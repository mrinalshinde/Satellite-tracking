# %% [markdown]
# # TLE Elements of Polar Satellite

# %%
import ephem

# %%
polar = ephem.readtle('POLAR',                   
'1 23802U 96013A   16314.47108496 -.00000183  00000-0  00000+0 0  9990',
'2 23802  78.3461 275.6297 7463437 332.0703   2.5102  1.29841886 99304')

# %% [markdown]
# # Plot Sub Satellite Point of Polar Satellite with time on World Map

# %%
import numpy as np
import time
import datetime
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import ephem

# %%
degrees_per_radian=180.0/np.pi
sub_lat_list = []
sub_long_list = []
alt_list = []
az_list = []
dist_list = []
overpass_alt = []
overpass_az = []
overpass_dist = []

# %%
obs = ephem.Observer()
obs.lat = 19.076
obs.lon = 72.8777
#obs.date = ephem.Date((2016, 12, 20, 0,0,0))

# %%
polar = ephem.readtle('POLAR',                   
'1 23802U 96013A   16329.87488456 -.00000385  00000-0  00000-0 0  9992',
'2 23802  78.3473 275.2322 7459027 331.4037   2.5576  1.29841842 99526')

# %%
plt.figure(figsize=(12,7))
map = Basemap(projection = 'cyl')
map.drawmapboundary(fill_color = 'white')
map.fillcontinents(color = 'brown',lake_color = 'blue')    
map.drawcoastlines()

# %%
x,y = map(obs.long,obs.lat)
map.plot(x,y,marker = '*',ms = 15, color = 'y')

# %%
pi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-68f7b1e53523> in <module>()
# ----> 1 pi
#
# NameError: name 'pi' is not defined

# %%
plt.figure(figsize=(12,7))
plt.xlabel("Time instant")
plt.ylabel("Distance")
plt.title("Measured distance from ground station vs Time")

# %%
for i in range(192):		##there are 96 hours between the 20th and the 24th december. Since, the interval is 30 mins, hence 192 iterations are taken
    #t.append(i)
    obs.date += 30*ephem.minute
    polar.compute(obs)
    sub_lat_list.append(polar.sublat*180/np.pi)
    sub_long_list.append(polar.sublong*180/np.pi)
    alt_list.append(polar.alt*180/np.pi)
    az_list.append(polar.az*180/np.pi)
    dist_list.append(polar.range)
    #if (polar.eclipsed is False):  
        #map.plot(sub_long_list[i],sub_lat_list[i],marker = 'o',ls = 'None',ms = 8,mfc = 'g',color = 'g')
    #else:
        #map.plot(sub_long_list[i],sub_lat_list[i],marker = 'o',ls = 'None',ms = 8, mfc = 'red',color = 'red') 
    #map.plot(sub_long_list,sub_lat_list,marker = 'o',ls = 'None',ms = 5, mfc = 'g',color = 'g')
    #if(polar.eclipsed is False):
        #plt.plot(az_list)
    #else:
        #plt.plot(az_list,'ro')

# %%
    #map.plot(alt_list,az_list,marker = 'x',ls = '--',ms = 5,mfc = 'r', color = 'g')
    #map.plot(dist_list,marker = '+',ms = 5, color = 'r')
    #print dist_list

# %%
#x = np.asarray(sub_long_list)
#y = np.asarray(sub_lat_list)
#map.plot(x,y,marker = 'o',ls = '--',ms = 7, mfc = 'r',color = 'g')
#plt.plot(i,dist_list)

# %%
plt.show()

# %%
plt.show()

# %%
plt.show()

# %%
polar.*?

# %%
polar_?
# Out:
# Object `polar_` not found.

# %%
Vr=polar.range_velocity

# %%
print Vr
# Out:
# -2057.31054688

# %%
print ephem.c
# Out:
# 299792458.0

# %%
f=6000000000

# %%
fd=(Vr*f)/ephem.c

# %%
print fd
# Out:
# -41174.6958666

# %%
plt.figure(figsize=(12,7))
plt.plot(alt_list)
plt.xlabel("Time instant")
plt.ylabel("Altitude")
plt.title("20 dec 2016 to 24 dec 2016 -- Altitude vs Time")

# %%
plt.show()

# %%
plt.figure(figsize=(12,7))
plt.plot(az_list)
plt.xlabel("Time instant")
plt.ylabel("Azimuth")
plt.title("20 dec 2016 to 24 dec 2016 -- Azimuth vs Time")
plt.show()

# %%
polar.*?

# %%
plt.figure(figsize=(12,7))
plt.xlabel("Time instant")
plt.ylabel("Altitude")
plt.title("20 dec 2016 to 24 dec 2016 -- Altitude vs Time")

# %%
plt.figure(figsize=(12,7))
plt.xlabel("Time instant")
plt.ylabel("Altitude")
plt.title("20 dec 2016 to 24 dec 2016 -- Altitude vs Time")
# Out:
#   File "<ipython-input-15-b255294ceca5>", line 9
#     else:
#          ^
# IndentationError: unindent does not match any outer indentation level

# %%
if(polar.eclipsed is False):
    plt.plot(alt_list)
    else:
        plt.plot(alt_list,'r--')
# Out:
#   File "<ipython-input-17-23bbabc2d632>", line 3
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
# Out:
#   File "<ipython-input-37-48f496d485b8>", line 3
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
plt.show()

# %%
plt.show()

# %%
if(polar.eclipsed is False):
    plt.plot(alt_list)
    else:
        plt.plot(alt_list,'ro')
# Out:
#   File "<ipython-input-6-62bd7e3c435e>", line 7
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
plt.show()

# %%
plt.plot(dist_list)
plt.show()

# %%
obs.date = ephem.now()
overpass = obs.next_pass(polar)
overpass_rise_time = overpass[0]
print overpass_rise_time
obs.date = overpass_rise_time
overpass = obs.next_pass(polar)
overpass_set_time = overpass[4]
print overpass_set_time
for i in range(16):
    polar.compute(obs)
    obs.date += 5*ephem.minute
    overpass_alt.append(polar.alt*180/np.pi)
    overpass_az.append(polar.az*180/np.pi)
    overpass_dist.append(polar.range)
# Out:
# 2017/2/21 23:41:59
# 2017/2/22 04:12:22

# %%
plt.figure(figsize=(12,7))
plt.plot(overpass_alt)
#name the axes and the title
plt.xlabel("Time instant")
plt.ylabel("Altitude")
plt.title("Measured for one overpass -- Altitude vs Time")

plt.show()

print overpass_alt
# Out:
# [0.0017764273990701859, 0.8159473115761228, 1.6768736599926009, 2.5693854711738626, 3.482701291515043, 4.40974472487089, 5.345870815718975, 6.287973322090819, 7.233779925426927, 8.181572833151039, 9.129947160728248, 10.07767859674983, 11.023640160002731, 11.96674414286163, 12.905906252795784, 13.840009753875899]

# %%
from scipy.special import erfinv

# %%
erfinv(1)
# Out:
# inf

# %%
erfcinv(0.4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-533a2277e50f> in <module>()
# ----> 1 erfcinv(0.4)
#
# NameError: name 'erfcinv' is not defined

# %%
erfinv(2*10^-6)
# Out:
# -inf

# %%
erfinv(1-(2*10^-6))
# Out:
# inf

# %%
import math

# %%
math.erfcinv(0.009)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-4c910e43b57e> in <module>()
# ----> 1 math.erfcinv(0.009)
#
# AttributeError: 'module' object has no attribute 'erfcinv'

# %%
for i=0
a=math.erfc(i);
if a=2*10^-6
